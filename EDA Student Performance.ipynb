# %%
## Student Performance

# The dataset is related to student performance and attributes in secondary education. Here's a general introduction based on the columns present in the DataFrame:

# This dataset contains information about students in secondary education, including demographic details, family background, educational support, lifestyle choices, and academic performance. Each row represents a unique student, and the columns provide various attributes and characteristics associated with them.

# %%
## Dataset contains following columns:

# * school: School attended by the student.
# * sex: Student's gender (male or female).
# * age: Student's age.
# * address: Type of address of the student (urban or rural).
# * famsize: Family size (binary categorization: "LE3" - less or equal to 3 or "GT3" - greater than 3).
# * Pstatus: Parent's cohabitation status (living together or apart).
# * Medu: Mother's education level (0 to 4, representing none to higher education).
# * Fedu: Father's education level (0 to 4, representing none to higher education).
# * Mjob: Mother's occupation.
# * Fjob: Father's occupation.
# * reason: Reason for choosing the school.
# * guardian: Student's guardian.
# * traveltime: Travel time to school.
# * studytime: Weekly study time (hours).
# * failures: Number of past class failures.
# * schoolsup: Extra educational support at school (yes or no).
# * famsup: Family educational support (yes or no).
# * paid: Extra paid classes within the course subject (yes or no).
# * activities: Extra-curricular activities (yes or no).
# * nursery: Attended nursery school (yes or no).
# * higher: Wants to take higher education (yes or no).
# * internet: Internet access at home (yes or no).
# * romantic: In a romantic relationship (yes or no).
# * famrel: Quality of family relationships (from 1 - very bad to 5 - excellent).
# * freetime: Free time after school (from 1 - very low to 5 - very high).
# * goout: Going out with friends (from 1 - very low to 5 - very high).
# * Dalc: Workday alcohol consumption (from 1 - very low to 5 - very high).
# * Walc: Weekend alcohol consumption (from 1 - very low to 5 - very high).
# * health: Current health status (from 1 - very bad to 5 - very good).
# * absences: Number of school absences.
# * G1: First period grade (from 0 to 20).
# * G2: Second period grade (from 0 to 20).
# * G3: Final grade (from 0 to 20).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('student-por.csv')

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
# There is no null values in the dataset

# %%
df.shape
# Out:
# (649, 33)

# %%
#univariate analysis

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df['school'].value_counts()
# Out:
# school
# GP    423
# MS    226
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x = 'school', data = df, palette='pastel')
plt.title("Dist of School")
plt.xlabel("School")
plt.ylabel("Count")
plt.show()

# %%
# GP has larger no of student

# %%
sns.histplot(df['age'], bins = 10, kde = True, palette='viridis')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# Most common age group >> 15 -16
# skeweed distribution

# %%
df['address'].value_counts()
# Out:
# address
# U    452
# R    197
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x = 'address', data = df, palette='dark')
plt.title("Dist of Student Address")
plt.xlabel("Adress")
plt.ylabel("Count")
plt.show()

# %%
# There are many student from urban area

# %%
df['reason'].unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
df['reason'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# common reason to join a school is course.

# %%
df['activities'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# 48.5 % students are participating

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df['Walc'].value_counts()
# Out:
# Walc
# 1    247
# 2    150
# 3    120
# 4     87
# 5     45
# Name: count, dtype: int64

# %%
# Insights >> 45 students have regular weekend alcohol consumnpltion

# %%
df['Walc'].value_counts().plot.pie(autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Dalc'].value_counts()
# Out:
# Dalc
# 1    451
# 2    121
# 3     43
# 5     17
# 4     17
# Name: count, dtype: int64

# %%
df['Dalc'].value_counts().plot.pie(autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# insight >> 17 student have regular alcohol consumption on weekdays.

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
sns.countplot(x = 'Medu', data = df, palette='Set2')
plt.xlabel("Mother Education Level")
plt.ylabel('Count')
plt.title("Mother Education Level Distribution")

plt.subplot(1,2,2)
sns.countplot(x = 'Fedu', data = df, palette='Set3')
plt.xlabel("Father Education Level")
plt.ylabel('Count')
plt.title("Father Education Level Distribution")

plt.show()

# %%
# Q."What is the relationship between the mother's education level and the father's education level?"

# %%
# Create a crosstab to count occurrences
edu_counts = pd.crosstab(df['Medu'], df['Fedu'])

# Plot a stacked bar chart
edu_counts.plot(kind='bar', stacked=True, colormap='viridis', figsize=(10, 6))
plt.xlabel("Mother's Education Level")
plt.ylabel("Count")
plt.title("Father's Education Level Distribution by Mother's Education Level")
plt.legend(title="Father's Education Level")
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(pd.crosstab(df['Medu'], df['Fedu']), annot=True, cmap="Blues", fmt='d')
plt.xlabel("Father's Education Level")
plt.ylabel("Mother's Education Level")
plt.title("Relationship Between Mother & Father Education Levels")
plt.show()

# %%
df['studytime']
# Out:
# 0      2
# 1      2
# 2      2
# 3      3
# 4      2
#       ..
# 644    3
# 645    2
# 646    2
# 647    1
# 648    1
# Name: studytime, Length: 649, dtype: int64

# %%
sns.barplot(x = 'studytime', y ='G3', data = df, palette='viridis')
# Out:
# <Axes: xlabel='studytime', ylabel='G3'>

# %%
sns.barplot(x = 'studytime', y ='G2', data = df, palette='viridis')
# Out:
# <Axes: xlabel='studytime', ylabel='G2'>

# %%
sns.barplot(x = 'internet', y ='G3', data = df, palette='viridis')
# Out:
# <Axes: xlabel='internet', ylabel='G3'>

# %%
# Multivariate Analysis

# %%
sns.barplot(x = 'sex', y = 'G3', hue = 'address', data = df, palette='Set2')
# Out:
# <Axes: xlabel='sex', ylabel='G3'>

# %%
num_cols = ['age','traveltime', 'studytime','absences', 'G1', 'G2', 'G3']

# %%
sns.boxplot(data = df[num_cols], palette='Set2')
# Out:
# <Axes: >

# %%
# Insights >> Median age 17

# %%
corr = df.corr(numeric_only=True)

# %%
plt.figure(figsize=(12,10))
sns.heatmap(corr, annot = True, cmap = "coolwarm", fmt = ".2f")
plt.show()

# %%
# insights >> strong positive correlation, strong negative correlation

# %%
# Outliers Detection

# %%
student_grades_df = df.copy()

# %%
student_grades_df.drop(['G1','G2','G3'] , axis = 1, inplace = True)

# %%
student_grades_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
def detect_outlier(columns):
    outlier_indices = []
    for column in columns:
        Q1 = student_grades_df[column].quantile(0.25)
        Q3 = student_grades_df[column].quantile(0.75)
        IQR = Q3 - Q1
        
        #mask is boolean condition
        mask = (student_grades_df[column] >= (Q1-1.5)*IQR) & (student_grades_df[column] <= (Q1+1.5)*IQR)

        mask = mask.to_numpy() # bool value to numpy array
        
        #find the indices of values that do not satisfy the mask condition >> that will be outlier
        false_indices = np.argwhere(~mask)
        outlier_indices.append(false_indices)
    return np.unique(np.concatenate(outlier_indices).ravel())

# %%
num_cols = ['age', 'absences']
outlier_indices = detect_outlier(num_cols)

# %%
# data split

# %%
student_grades_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
X = student_grades_df.iloc[:,:-1]
Y = student_grades_df.iloc[:,-1]

# %%
X
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
Y
# Out:
# 0      4
# 1      2
# 2      6
# 3      0
# 4      0
#       ..
# 644    4
# 645    4
# 646    6
# 647    6
# 648    4
# Name: absences, Length: 649, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=1)

# %%
#encoding of data

# %%
cat_features = X.select_dtypes(include='object').columns
num_features = X.select_dtypes(exclude='object').columns

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

numeric_transformer = StandardScaler()
oh_transformer = OneHotEncoder(drop = 'first') #n features>> n-1 dummy features will be enough to explain everything

preprocessor = ColumnTransformer(
    [
        ("OneHotEncoder", oh_transformer, cat_features),
        ("StandardScaler", numeric_transformer, num_features)
    ]
)

# %%
X_train = preprocessor.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.        ,  0.        ,  1.        , ..., -0.51854929,
#         -0.2116755 , -0.38087754],
#        [ 0.        ,  1.        ,  1.        , ..., -0.51854929,
#         -0.9910262 ,  0.9902816 ],
#        [ 0.        ,  1.        ,  1.        , ..., -0.51854929,
#         -0.2116755 ,  0.9902816 ],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.54033707,
#          1.34702591,  0.9902816 ],
#        [ 0.        ,  0.        ,  1.        , ..., -0.51854929,
#         -0.9910262 ,  0.9902816 ],
#        [ 0.        ,  1.        ,  0.        , ..., -0.51854929,
#         -0.9910262 ,  0.9902816 ]])

# %%
X_test = preprocessor.transform(X_test)

# %%
X_test
# Out:
# array([[ 1.        ,  1.        ,  1.        , ...,  2.65810978,
#          2.12637661, -0.38087754],
#        [ 0.        ,  1.        ,  1.        , ...,  2.65810978,
#          2.12637661, -0.38087754],
#        [ 1.        ,  0.        ,  1.        , ...,  0.54033707,
#          0.5676752 ,  0.9902816 ],
#        ...,
#        [ 1.        ,  0.        ,  0.        , ..., -0.51854929,
#          0.5676752 , -0.38087754],
#        [ 0.        ,  0.        ,  1.        , ..., -0.51854929,
#         -0.9910262 , -0.38087754],
#        [ 0.        ,  0.        ,  0.        , ...,  0.54033707,
#          0.5676752 , -0.38087754]])
